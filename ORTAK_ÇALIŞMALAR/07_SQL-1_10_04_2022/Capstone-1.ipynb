# %%
import pyodbc

# %%
import numpy as np
import pandas as pd
import json
# Görselleştirme
import seaborn as sns
import matplotlib.pyplot as plt

import pandas.io.sql
from datetime import datetime
now = datetime.now() # current date and time
from scipy import misc
import scipy

# %%
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      'SERVER=94.73.146.3,1433;'
                      'DATABASE=u0583688_Covid; UID=u0583688_Covid; PWD=ScCovid0821/*-1;')

# %%
sql="SELECT * FROM Covid_EUR"

# %%
df = pandas.io.sql.read_sql(sql, conn)
# Out:
# C:\Users\Toshiba\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df=df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37789 entries, 0 to 37788
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PEOPLE_POSITIVE_CASES_COUNT      37789 non-null  int64
#  1   COUNTY_NAME                      0 non-null      object
#  2   PROVINCE_STATE_NAME              0 non-null      object
#  3   REPORT_DATE                      37789 non-null  datetime64[ns]
#  4   REPORT_DATE1                     37789 non-null  object
#  5   CONTINENT_NAME                   37789 non-null  object
#  6   DATA_SOURCE_NAME                 37789 non-null  object
#  7   PEOPLE_DEATH_NEW_COUNT           37789 non-null  int64
#  8   COUNTY_FIPS_NUMBER               0 non-null      object
#  9   COUNTRY_ALPHA_3_CODE             37789 non-null  object
#  10  COUNTRY_SHORT_NAME               37789 non-null  object
# ...

# %%
df
# Out:
#        PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME  \
# 0                           823078        None                None
# 1                           827111        None                None
# 2                           828347        None                None
# 3                           830251        None                None
# 4                           831881        None                None
# ...                            ...         ...                 ...
# 37784                            1        None                None
# 37785                            1        None                None
# 37786                            0        None                None
# 37787                            0        None                None
# 37788                            0        None                None
#
#       REPORT_DATE REPORT_DATE1 CONTINENT_NAME            DATA_SOURCE_NAME  \
# 0      2021-09-19   2021-09-19         Europe  JHU CSSE Global Timeseries
# ...

# %%
df.describe().T
# Out:
#                                    count           mean           std  \
# PEOPLE_POSITIVE_CASES_COUNT      37789.0  548597.073275  1.296714e+06
# PEOPLE_DEATH_NEW_COUNT           37789.0      41.335494  1.256247e+02
# PEOPLE_POSITIVE_NEW_CASES_COUNT  37789.0    2385.640424  7.641967e+03
# PEOPLE_DEATH_COUNT               37789.0   12356.390378  2.915475e+04
#
#                                       min     25%      50%       75%  \
# PEOPLE_POSITIVE_CASES_COUNT           0.0  2677.0  63262.0  371712.0
# PEOPLE_DEATH_NEW_COUNT            -1918.0     0.0      2.0      20.0
# PEOPLE_POSITIVE_NEW_CASES_COUNT -349116.0     7.0    211.0    1337.0
# PEOPLE_DEATH_COUNT                    0.0    48.0   1008.0    8959.0
#
#                                         max
# PEOPLE_POSITIVE_CASES_COUNT      12937886.0
# PEOPLE_DEATH_NEW_COUNT               1820.0
# PEOPLE_POSITIVE_NEW_CASES_COUNT    232200.0
# PEOPLE_DEATH_COUNT                 302671.0

# %%
df = df.to_csv("covid.csv")

# %%
#import pypyodbc
connection = pyodbc.connect('Driver={SQL Native Client};Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql')

cursor = connection.cursor()
cursor.execute("SELECT * FROM Query")
sonuc = cursor.fetchall()
for i in sonuc:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24900/3762785072.py in <module>
#       1 #import pypyodbc
# ----> 2 connection = pyodbc.connect('Driver={SQL Native Client};Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql')
#       3
#       4 cursor = connection.cursor()
#       5 cursor.execute("SELECT * FROM Query")
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Veri kaynağı adı bulunamadı ve varsayılan sürücü belirtilmemiş (0) (SQLDriverConnect)')

# %%
Driver={SQL Native Client};Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql
# Out:
#   File "C:\Users\sc977\AppData\Local\Temp/ipykernel_24900/2486206437.py", line 1
#     Driver={SQL Native Client};Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql
#                 ^
# SyntaxError: invalid syntax

# %%
# Parameters
server = '94.73.145.9'
db = 'u0583688_eksDB'
# Create the connection

#conn = pyodbc.connect('DRIVER={SQL Server};SERVER=DESKTOP-4GVE7IT; DATABASE=SampleRetail; Trusted_Connection=yes')
#conn = pyodbc.connect('Driver={SQL Server Native Client 10.0};Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql')
conn = pyodbc.connect('Provider=SQLNCLI10;Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql')


#Provider=SQLNCLI10;Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=S***********************;

#sql = "SELECT  * FROM product.product"
#brand = "SELECT  * FROM product.brand"
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24900/1456329209.py in <module>
#       6 #conn = pyodbc.connect('DRIVER={SQL Server};SERVER=DESKTOP-4GVE7IT; DATABASE=SampleRetail; Trusted_Connection=yes')
#       7 #conn = pyodbc.connect('Driver={SQL Server Native Client 10.0};Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql')
# ----> 8 conn = pyodbc.connect('Provider=SQLNCLI10;Server=94.73.145.9;Database=u0583688_eksDB; Uid=u0583688_eksUS;Pwd=Sc1234566sqlSc1234566sql')
#       9
#      10
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Veri kaynağı adı bulunamadı ve varsayılan sürücü belirtilmemiş (0) (SQLDriverConnect)')

# %%
df = pandas.io.sql.read_sql(sql, conn)
brand = pandas.io.sql.read_sql(brand, conn)

# %%
df.head()
# Out:
#    product_id                                       product_name  brand_id  \
# 0           1  DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 ...        23
# 1           2  NS-SP1800BL 5.1-Channel Home Theater System (B...         5
# 2           3  Acoustimass 6 Series V Home Theater Speaker Sy...        24
# 3           4  Corsair Vengeance LPX 16GB (2x8GB) DDR4 DRAM 3...         6
# 4           5  Details About Samsung Gear Iconx 2018 Edition ...         1
#
#    category_id  model_year  list_price
# 0            4        2021       23.99
# 1            5        2021      136.99
# 2            5        2021      599.00
# 3            4        2021      151.99
# 4           14        2021      199.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    520 non-null    int64
#  1   product_name  520 non-null    object
#  2   brand_id      520 non-null    int64
#  3   category_id   520 non-null    int64
#  4   model_year    520 non-null    int64
#  5   list_price    520 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 24.5+ KB

# %%
df2=df.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    520 non-null    int64
#  1   product_name  520 non-null    object
#  2   brand_id      520 non-null    int64
#  3   category_id   520 non-null    int64
#  4   model_year    520 non-null    int64
#  5   list_price    520 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 24.5+ KB

# %%
df2.groupby['product_name'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8676/1328281516.py in <module>
# ----> 1 df2.groupby['product_name'].sum()
#
# TypeError: 'method' object is not subscriptable

# %%
brand.groupby(['brand_name']).count()
# Out:
#                        brand_id
# brand_name
# Acer                          1
# Alpine                        1
# Apple                         1
# Asus                          1
# AudioQuest                    1
# BenQ                          1
# Bose                          1
# Corsair                       1
# DENAQ                         1
# Definitive Technology         1
# Dell                          1
# House Of Marley               1
# Jbl                           1
# Kenwood                       1
# Klipsch                       1
# Lenovo                        1
# Logitech                      1
# Marantz                       1
# Microsoft                     1
# Netgear                       1
# Pioneer                       1
# Pny                           1
# Polk Audio                    1
# Razer                         1
# Russound                      1
# Samsung                       1
# Sandisk                       1
# Seagate                       1
# ...

# %%
df.describe().T
# Out:
#         count          mean           std           min           25%  \
# V1   854421.0 -7.505882e+13  3.834311e+14 -9.999911e+14 -2.795382e+14
# V2   854421.0  2.340342e+13  4.611944e+14 -9.999968e+14 -2.478007e+14
# V3   854421.0  3.729228e+13  4.172909e+14 -9.999929e+14 -1.929494e+14
# V4   854421.0 -1.009763e+13  4.445685e+14 -9.999950e+14 -2.507393e+14
# V5   854421.0 -2.004330e+13  4.566269e+14 -9.999780e+14 -2.974904e+14
# V6   854421.0 -1.135441e+14  4.598274e+14 -9.999724e+14 -4.650924e+14
# V7   854421.0  2.008460e+13  4.814223e+14 -9.999925e+14 -2.986695e+14
# V8   854421.0  3.819159e+13  4.357332e+14 -9.999802e+14 -2.544460e+14
# V9   854421.0 -1.991807e+13  4.516852e+14 -9.999833e+14 -2.825966e+14
# V10  854421.0 -4.396877e+13  4.663214e+14 -9.999664e+14 -3.580501e+14
# V11  854421.0 -1.174349e+13  4.641241e+14 -9.999758e+14 -2.507316e+14
# V12  854421.0  7.871339e+13  4.657412e+14 -9.999902e+14 -2.295481e+14
# ...
